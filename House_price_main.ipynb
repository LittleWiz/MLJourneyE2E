# %%
# Import the DataIngestor class from the eda module
from eda.data_ingestor import DataIngestor
from eda.data_inspector import DataInspector
from eda.data_analyser import DataAnalyser
from eda.data_preprocessor import DataPreprocessor

# %%
# Create an instance pointing to your data folder
ingestor = DataIngestor(data_dir='data')

# %%
# Load the first file from the zip into a DataFrame
df = ingestor.load_data_file()

# Display the first few rows
df.head(3)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2  2000-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            69.0        Improved                 1986      147000.0
# 1            61.0        Improved                 1986      144000.0
# 2            73.0  New Generation                 1976      159000.0
#
#                                          source_file remaining_lease
# 0  Resale Flat Prices (Based on Approval Date), 2...             NaN
# 1  Resale Flat Prices (Based on Approval Date), 2...             NaN
# 2  Resale Flat Prices (Based on Approval Date), 2...             NaN

# %%
df.shape
# Out:
# (956046, 14)

# %%
inspector = DataInspector(df)

inspection_df = inspector.inspect_all()

# %%
inspection_df
# Out:
# {'shape': (957961, 12),
#  'dtypes': month                   object
#  town                    object
#  flat_type               object
#  block                   object
#  street_name             object
#  storey_range            object
#  floor_area_sqm         float64
#  flat_model              object
#  lease_commence_date      int64
#  resale_price           float64
#  source_file             object
#  remaining_lease         object
#  dtype: object,
#  'null_percentages': month                   0.000000
#  town                    0.000000
#  flat_type               0.000000
#  block                   0.000000
#  street_name             0.000000
#  storey_range            0.000000
#  floor_area_sqm          0.000000
#  flat_model              0.000000
#  lease_commence_date     0.000000
#  resale_price            0.000000
#  source_file             0.000000
#  remaining_lease        74.016583
#  dtype: float64,
# ...

# %%
analyser = DataAnalyser(df)

# Identify columns
numeric_cols, category_cols = analyser.identify_columns()

# Print unique values for categorical columns
analyser.print_category_values()

# Plot numeric columns
analyser.plot_numeric()

# Plot categorical columns
analyser.plot_categorical()
# Out:
# month: ['2000-01' '2000-02' '2000-03' '2000-04' '2000-05' '2000-06' '2000-07'
#  '2000-08' '2000-09' '2000-10' '2000-11' '2000-12' '2001-01' '2001-02'
#  '2001-03' '2001-04' '2001-05' '2001-06' '2001-07' '2001-08' '2001-09'
#  '2001-10' '2001-11' '2001-12' '2002-01' '2002-02' '2002-03' '2002-04'
#  '2002-05' '2002-06' '2002-07' '2002-08' '2002-09' '2002-10' '2002-11'
#  '2002-12' '2003-01' '2003-02' '2003-03' '2003-04' '2003-05' '2003-06'
#  '2003-07' '2003-08' '2003-09' '2003-10' '2003-11' '2003-12' '2004-01'
#  '2004-02' '2004-03' '2004-04' '2004-05' '2004-06' '2004-07' '2004-08'
#  '2004-09' '2004-10' '2004-11' '2004-12' '2005-01' '2005-02' '2005-03'
#  '2005-04' '2005-05' '2005-06' '2005-07' '2005-08' '2005-09' '2005-10'
#  '2005-11' '2005-12' '2006-01' '2006-02' '2006-03' '2006-04' '2006-05'
#  '2006-06' '2006-07' '2006-08' '2006-09' '2006-10' '2006-11' '2006-12'
#  '2007-01' '2007-02' '2007-03' '2007-04' '2007-05' '2007-06' '2007-07'
# ...

# %%
analyser.plot_covariance_heatmap()

# %%
# Preprocess the DataFrame
preprocessor = DataPreprocessor(df)
df = preprocessor.preprocess_all()

# Display the first few rows after preprocessing
df.head(3)
# Out:
#        month        town flat_type block       street_name  floor_area_sqm  \
# 0 2000-01-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4            69.0
# 1 2000-01-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4            61.0
# 2 2000-01-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1            73.0
#
#        flat_model  lease_commence_date  resale_price  \
# 0        Improved                 1986      147000.0
# 1        Improved                 1986      144000.0
# 2  New Generation                 1976      159000.0
#
#                                          source_file  storey_min  storey_max  \
# 0  Resale Flat Prices (Based on Approval Date), 2...           7           9
# 1  Resale Flat Prices (Based on Approval Date), 2...           4           6
# 2  Resale Flat Prices (Based on Approval Date), 2...           7           9
#
#    storey_mean  remaining_lease_years
# 0          8.0                -1000.0
# 1          5.0                -1000.0
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (956046, 14)
